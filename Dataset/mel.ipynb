# %%
pip install librosa
# Out:
# Requirement already satisfied: librosa in c:\users\g ravisankar\anaconda3\lib\site-packages (0.10.2.post1)
# Requirement already satisfied: decorator>=4.3.0 in c:\users\g ravisankar\anaconda3\lib\site-packages (from librosa) (5.1.1)
# Requirement already satisfied: joblib>=0.14 in c:\users\g ravisankar\anaconda3\lib\site-packages (from librosa) (1.1.1)
# Requirement already satisfied: typing-extensions>=4.1.1 in c:\users\g ravisankar\anaconda3\lib\site-packages (from librosa) (4.4.0)
# Requirement already satisfied: pooch>=1.1 in c:\users\g ravisankar\anaconda3\lib\site-packages (from librosa) (1.4.0)
# Requirement already satisfied: audioread>=2.1.9 in c:\users\g ravisankar\anaconda3\lib\site-packages (from librosa) (3.0.1)
# Requirement already satisfied: soxr>=0.3.2 in c:\users\g ravisankar\anaconda3\lib\site-packages (from librosa) (0.5.0.post1)
# Requirement already satisfied: numba>=0.51.0 in c:\users\g ravisankar\anaconda3\lib\site-packages (from librosa) (0.56.4)
# Requirement already satisfied: scipy>=1.2.0 in c:\users\g ravisankar\anaconda3\lib\site-packages (from librosa) (1.10.0)
# Requirement already satisfied: numpy!=1.22.0,!=1.22.1,!=1.22.2,>=1.20.3 in c:\users\g ravisankar\anaconda3\lib\site-packages (from librosa) (1.23.5)
# Requirement already satisfied: lazy-loader>=0.1 in c:\users\g ravisankar\anaconda3\lib\site-packages (from librosa) (0.4)
# Requirement already satisfied: soundfile>=0.12.1 in c:\users\g ravisankar\anaconda3\lib\site-packages (from librosa) (0.13.1)
# Requirement already satisfied: scikit-learn>=0.20.0 in c:\users\g ravisankar\anaconda3\lib\site-packages (from librosa) (1.2.1)
# Requirement already satisfied: msgpack>=1.0 in c:\users\g ravisankar\anaconda3\lib\site-packages (from librosa) (1.0.3)
# Requirement already satisfied: packaging in c:\users\g ravisankar\anaconda3\lib\site-packages (from lazy-loader>=0.1->librosa) (22.0)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in c:\users\g ravisankar\anaconda3\lib\site-packages (from numba>=0.51.0->librosa) (0.39.1)
# Requirement already satisfied: setuptools in c:\users\g ravisankar\anaconda3\lib\site-packages (from numba>=0.51.0->librosa) (65.6.3)
# Requirement already satisfied: appdirs in c:\users\g ravisankar\anaconda3\lib\site-packages (from pooch>=1.1->librosa) (1.4.4)
# Requirement already satisfied: requests in c:\users\g ravisankar\anaconda3\lib\site-packages (from pooch>=1.1->librosa) (2.28.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\g ravisankar\anaconda3\lib\site-packages (from scikit-learn>=0.20.0->librosa) (2.2.0)
# Requirement already satisfied: cffi>=1.0 in c:\users\g ravisankar\anaconda3\lib\site-packages (from soundfile>=0.12.1->librosa) (1.15.1)
# Requirement already satisfied: pycparser in c:\users\g ravisankar\anaconda3\lib\site-packages (from cffi>=1.0->soundfile>=0.12.1->librosa) (2.21)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\g ravisankar\anaconda3\lib\site-packages (from requests->pooch>=1.1->librosa) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\g ravisankar\anaconda3\lib\site-packages (from requests->pooch>=1.1->librosa) (1.26.14)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\g ravisankar\anaconda3\lib\site-packages (from requests->pooch>=1.1->librosa) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\g ravisankar\anaconda3\lib\site-packages (from requests->pooch>=1.1->librosa) (2023.5.7)
# Note: you may need to restart the kernel to use updated packages.

# %%
import librosa
import librosa.display
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
def load_audio(file_path):
    y, sr = librosa.load(file_path, sr=None)
    return y, sr

# %%
def save_plot(fig, output_folder, feature, file_name):
    folder_path = os.path.join(output_folder, feature)
    os.makedirs(folder_path, exist_ok=True)
    file_path = os.path.join(folder_path, file_name)
    fig.savefig(file_path)
    plt.close(fig)

# %%
def plot_spectral_bandwidth(y, sr, title, output_folder):
    spectral_bandwidth = librosa.feature.spectral_bandwidth(y=y, sr=sr)
    fig = plt.figure(figsize=(10, 4))
    plt.semilogy(spectral_bandwidth.T, label='Spectral Bandwidth')
    plt.title(f'Spectral Bandwidth - {title}')
    plt.xlabel('Frames')
    plt.ylabel('Frequency (Hz)')
    plt.legend()
    save_plot(fig, output_folder, 'Spectral_Bandwidth', f'{title}_spectral_bandwidth.png')

# %%
def plot_spectral_contrast(y, sr, title, output_folder):
    spectral_contrast = librosa.feature.spectral_contrast(y=y, sr=sr)
    fig = plt.figure(figsize=(10, 4))
    librosa.display.specshow(spectral_contrast, x_axis='time', sr=sr)
    plt.colorbar()
    plt.title(f'Spectral Contrast - {title}')
    save_plot(fig, output_folder, 'Spectral_Contrast', f'{title}_spectral_contrast.png')

# %%
def plot_spectral_flatness(y, sr, title, output_folder):
    spectral_flatness = librosa.feature.spectral_flatness(y=y)
    fig = plt.figure(figsize=(10, 4))
    plt.plot(spectral_flatness.T, label='Spectral Flatness')
    plt.title(f'Spectral Flatness - {title}')
    plt.xlabel('Frames')
    plt.ylabel('Flatness')
    plt.legend()
    save_plot(fig, output_folder, 'Spectral_Flatness', f'{title}_spectral_flatness.png')

# %%
def plot_waveform(y, sr, title):
    plt.figure(figsize=(10, 4))
    librosa.display.waveshow(y, sr=sr)
    plt.title(f'Amplitude Waveform - {title}')
    plt.xlabel('Time (s)')
    plt.ylabel('Amplitude')
    plt.show()

def plot_mfcc(y, sr, title):
    mfccs = librosa.feature.mfcc(y=y, sr=sr, n_mfcc=13)
    plt.figure(figsize=(10, 4))
    librosa.display.specshow(mfccs, x_axis='time', sr=sr)
    plt.colorbar()
    plt.title(f'MFCC - {title}')
    plt.xlabel('Time (s)')
    plt.ylabel('MFCC Coefficients')
    plt.show()

def plot_mel_spectrogram(y, sr, title):
    mel_spec = librosa.feature.melspectrogram(y=y, sr=sr)
    mel_spec_db = librosa.power_to_db(mel_spec, ref=np.max)
    plt.figure(figsize=(10, 4))
    librosa.display.specshow(mel_spec_db, x_axis='time', y_axis='mel', sr=sr)
    plt.colorbar()
    plt.title(f'Mel Spectrogram - {title}')
    plt.show()

def plot_zero_crossing_rate(y, sr, title):
    zcr = librosa.feature.zero_crossing_rate(y)
    plt.figure(figsize=(10, 4))
    plt.plot(zcr[0], label='Zero Crossing Rate')
    plt.title(f'Zero-Crossing Rate - {title}')
    plt.xlabel('Frames')
    plt.ylabel('ZCR')
    plt.legend()
    plt.show()

def plot_spectral_centroid(y, sr, title):
    spectral_centroid = librosa.feature.spectral_centroid(y=y, sr=sr)
    plt.figure(figsize=(10, 4))
    plt.semilogy(spectral_centroid.T, label='Spectral Centroid')
    plt.title(f'Spectral Centroid - {title}')
    plt.xlabel('Frames')
    plt.ylabel('Frequency (Hz)')
    plt.legend()
    plt.show()

# %%
def analyze_audio_features(folder_path, output_folder):
    for file_name in os.listdir(folder_path):
        if file_name.endswith('.wav'):
            file_path = os.path.join(folder_path, file_name)
            y, sr = load_audio(file_path)
            title = os.path.splitext(file_name)[0]
            print(f'Analyzing: {title}')
            plot_waveform(y, sr, title)
            plot_mfcc(y, sr, title)
            plot_mel_spectrogram(y, sr, title)
            plot_zero_crossing_rate(y, sr, title)
            plot_spectral_centroid(y, sr, title)
            plot_spectral_bandwidth(y, sr, title, output_folder)
            plot_spectral_contrast(y, sr, title, output_folder)
            plot_spectral_flatness(y, sr, title, output_folder)

# %%
audio_folder = ""
output_folder = ""

# %%
analyze_audio_features(audio_folder, output_folder)
# Analyzing: p267_345
# Analyzing: p267_346
# Analyzing: p267_347
# Analyzing: p267_348
# Analyzing: p267_349
# Analyzing: p267_350
# Analyzing: p267_351
# Analyzing: p267_352
# Analyzing: p267_353
# Analyzing: p267_354
# Analyzing: p267_355
# Analyzing: p267_356
# Analyzing: p267_358
# Analyzing: p267_359
# Analyzing: p267_360
# Analyzing: p267_362
# Analyzing: p267_364
# Analyzing: p267_365
# Analyzing: p267_366
# Analyzing: p267_367
# Analyzing: p267_368
# Analyzing: p267_369
# Analyzing: p267_370
# Analyzing: p267_371
# Analyzing: p267_372
# Analyzing: p267_373
# Analyzing: p267_374
# Analyzing: p267_375
# Analyzing: p267_376
# Analyzing: p267_377
# Analyzing: p267_378
# Analyzing: p267_379
# Analyzing: p267_380
# Analyzing: p267_381
# Analyzing: p267_382
# Analyzing: p267_383
# Analyzing: p267_384
# Analyzing: p267_385
# Analyzing: p267_386
# Analyzing: p267_387
# Analyzing: p267_388
# Analyzing: p267_389
# Analyzing: p267_390
# Analyzing: p267_391
# Analyzing: p267_392
# Analyzing: p267_393
# Analyzing: p267_394
# Analyzing: p267_395
# Analyzing: p267_396
# Analyzing: p267_397
# Analyzing: p267_398
# Analyzing: p267_399
# Analyzing: p267_400
# Analyzing: p267_401
# Analyzing: p267_402
# Analyzing: p267_403
# Analyzing: p267_404
# Analyzing: p267_405
# Analyzing: p267_406
# Analyzing: p267_407
# Analyzing: p267_408
# Analyzing: p267_409
# Analyzing: p267_410
# Analyzing: p267_411
# Analyzing: p267_412
# Analyzing: p267_413
# Analyzing: p267_414
# Analyzing: p267_416
# Analyzing: p267_417
# Analyzing: p267_418
# Analyzing: p267_419
# Analyzing: p267_420
# Analyzing: p267_421
# Analyzing: p268_001
# Analyzing: p268_002
# Analyzing: p268_003
# Analyzing: p268_004
# Analyzing: p268_005
# Analyzing: p268_006
# Analyzing: p268_007
# Analyzing: p268_009
# Analyzing: p268_010
# Analyzing: p268_011
# Analyzing: p268_012
# Analyzing: p268_013
# Analyzing: p268_014
# Analyzing: p268_015
# Analyzing: p268_016
# Analyzing: p268_017
# Analyzing: p268_018
# Analyzing: p268_019
# Analyzing: p268_020
# Analyzing: p268_021
# Analyzing: p268_022
# Analyzing: p268_024
# Analyzing: p268_025
# Analyzing: p268_026
# Analyzing: p268_027
# Analyzing: p268_028
# Analyzing: p268_029
# Analyzing: p268_030
# Analyzing: p268_031
# Analyzing: p268_032
# Analyzing: p268_033
# Analyzing: p268_034
# Analyzing: p268_035
# Analyzing: p268_036
# Analyzing: p268_037
# Analyzing: p268_038
# Analyzing: p268_039
# Analyzing: p268_040
# Analyzing: p268_041
# Analyzing: p268_042
# Analyzing: p268_043
# Analyzing: p268_044
# Analyzing: p268_045
# Analyzing: p268_046
# Analyzing: p268_047
# Analyzing: p268_048
# Analyzing: p268_049
# Analyzing: p268_050
# Analyzing: p268_051
# Analyzing: p268_052
# Analyzing: p268_053
# Analyzing: p268_054
# Analyzing: p268_055
# Analyzing: p268_056
# Analyzing: p268_057
# Analyzing: p268_058
# Analyzing: p268_059
# Analyzing: p268_060
# Analyzing: p268_061
# Analyzing: p268_062
# Analyzing: p268_063
# Analyzing: p268_064
# Analyzing: p268_065
# Analyzing: p268_066
# Analyzing: p268_067
# Analyzing: p268_068
# Analyzing: p268_069
# Analyzing: p268_070
# Analyzing: p268_071
# Analyzing: p268_072
# Analyzing: p268_073
# Analyzing: p268_074
# Analyzing: p268_075
# Analyzing: p268_076
# Analyzing: p268_077
# Analyzing: p268_078
# Analyzing: p268_079
# Analyzing: p268_080
# Analyzing: p268_081
# Analyzing: p268_082
# Analyzing: p268_083
# Analyzing: p268_084
# Analyzing: p268_085
# Analyzing: p268_086
# Analyzing: p268_087
# Analyzing: p268_088
# Analyzing: p268_089
# Analyzing: p268_090
# Analyzing: p268_091
# Analyzing: p268_092
# Analyzing: p268_093
# Analyzing: p268_094
# Analyzing: p268_095
# Analyzing: p268_096
# Analyzing: p268_097
# Analyzing: p268_098
# Analyzing: p268_099
# Analyzing: p268_100
# Analyzing: p268_101
# Analyzing: p268_102
# Analyzing: p268_103
# Analyzing: p268_104
# Analyzing: p268_105
# Analyzing: p268_106
# Analyzing: p268_107
# Analyzing: p268_108
# Analyzing: p268_109
# Analyzing: p268_110
# Analyzing: p268_111
# Analyzing: p268_112
# Analyzing: p268_113
# Analyzing: p268_114
# Analyzing: p268_115
# Analyzing: p268_116
# Analyzing: p268_117
# Analyzing: p268_118
# Analyzing: p268_119
# Analyzing: p268_120
# Analyzing: p268_121
# Analyzing: p268_122
# Analyzing: p268_123
# Analyzing: p268_124
# Analyzing: p268_125
# Analyzing: p268_126
# Analyzing: p268_127
# Analyzing: p268_128
# Analyzing: p268_129
# Analyzing: p268_130
# Analyzing: p268_131
# Analyzing: p268_132
# Analyzing: p268_133
# Analyzing: p268_134
# Analyzing: p268_135
# Analyzing: p268_137
# Analyzing: p268_138
# Analyzing: p268_139
# Analyzing: p268_140
# Analyzing: p268_141
# Analyzing: p268_142
# Analyzing: p268_143
# Analyzing: p268_144
# Analyzing: p268_145
# Analyzing: p268_146
# Analyzing: p268_147
# Analyzing: p268_148
# Analyzing: p268_149
# Analyzing: p268_150
# Analyzing: p268_151
# Analyzing: p268_152
# Analyzing: p268_153
# Analyzing: p268_154
# Analyzing: p268_155
# Analyzing: p268_156
# Analyzing: p268_157
# Analyzing: p268_158
# Analyzing: p268_160
# Analyzing: p268_161
# Analyzing: p268_162
# Analyzing: p268_163
# Analyzing: p268_164
# Analyzing: p268_165
# Analyzing: p268_166
# Analyzing: p268_167
# Analyzing: p268_168
# Analyzing: p268_169
# Analyzing: p268_170
# Analyzing: p268_171
# Analyzing: p268_172
# Analyzing: p268_173
# Analyzing: p268_174
# Analyzing: p268_175
# Analyzing: p268_176
# Analyzing: p268_177
# Analyzing: p268_178
# Analyzing: p268_179
# Analyzing: p268_180
# Analyzing: p268_181
# Analyzing: p268_182
# Analyzing: p268_183
# Analyzing: p268_184
# Analyzing: p268_185
# Analyzing: p268_186
# Analyzing: p268_187
# Analyzing: p268_188
# Analyzing: p268_189
# Analyzing: p268_190
# Analyzing: p268_191
# Analyzing: p268_192
# Analyzing: p268_193
# Analyzing: p268_194
# Analyzing: p268_195
# Analyzing: p268_196
# Analyzing: p268_197
# Analyzing: p268_198
# Analyzing: p268_199
# Analyzing: p268_200
# Analyzing: p268_201
# Analyzing: p268_202
# Analyzing: p268_203
# Analyzing: p268_204
# Analyzing: p268_205
# Analyzing: p268_206
# Analyzing: p268_207
# Analyzing: p268_208
# Analyzing: p268_209
# Analyzing: p268_210
# Analyzing: p268_211
# Analyzing: p268_212
# Analyzing: p268_213
# Analyzing: p268_214
# Analyzing: p268_215
# Analyzing: p268_216
# Analyzing: p268_217
# Analyzing: p268_218
# Analyzing: p268_219
# Analyzing: p268_220
# Analyzing: p268_221
# Analyzing: p268_222
# Analyzing: p268_223
# Analyzing: p268_224
# Analyzing: p268_225
# Analyzing: p268_226
# Analyzing: p268_227
# Analyzing: p268_228
# Analyzing: p268_229
# Analyzing: p268_230
# Analyzing: p268_231
# Analyzing: p268_232
# Analyzing: p268_233
# Analyzing: p268_234
# Analyzing: p268_235
# Analyzing: p268_236
# Analyzing: p268_237
# Analyzing: p268_238
# Analyzing: p268_239
# Analyzing: p268_240
# Analyzing: p268_241
# Analyzing: p268_242
# Analyzing: p268_243
# Analyzing: p268_244
# Analyzing: p268_245
# Analyzing: p268_246
# Analyzing: p268_247
# Analyzing: p268_248
# Analyzing: p268_249
# Analyzing: p268_250
# Analyzing: p268_251
# Analyzing: p268_252
# Analyzing: p268_253
# Analyzing: p268_254
# Analyzing: p268_255
# Analyzing: p268_256
# Analyzing: p268_257
# Analyzing: p268_258
# Analyzing: p268_259
# Analyzing: p268_260
# Analyzing: p268_261
# Analyzing: p268_262
# Analyzing: p268_263
# Analyzing: p268_264
# Analyzing: p268_265
# Analyzing: p268_266
# Analyzing: p268_267
# Analyzing: p268_268
# Analyzing: p268_269
# Analyzing: p268_270
# Analyzing: p268_271
# Analyzing: p268_272
# Analyzing: p268_273
# Analyzing: p268_274
# Analyzing: p268_275
# Analyzing: p268_276
# Analyzing: p268_277
# Analyzing: p268_278
# Analyzing: p268_279
# Analyzing: p268_280
# Analyzing: p268_282
# Analyzing: p268_283
# Analyzing: p268_284
# Analyzing: p268_285
# Analyzing: p268_286
# Analyzing: p268_287
# Analyzing: p268_288
# Analyzing: p268_289
# Analyzing: p268_290
# Analyzing: p268_291
# Analyzing: p268_292
# Analyzing: p268_293
# Analyzing: p268_294
# Analyzing: p268_295
# Analyzing: p268_296
# Analyzing: p268_297
# Analyzing: p268_298
# Analyzing: p268_299
# Analyzing: p268_300
# Analyzing: p268_301
# Analyzing: p268_302
# Analyzing: p268_303
# Analyzing: p268_304
# Analyzing: p268_305
# Analyzing: p268_306
# Analyzing: p268_307
# Analyzing: p268_308
# Analyzing: p268_309
# Analyzing: p268_310
# Analyzing: p268_311
# Analyzing: p268_312
# Analyzing: p268_313
# Analyzing: p268_314
# Analyzing: p268_315
# Analyzing: p268_316
# Analyzing: p268_317
# Analyzing: p268_318
# Analyzing: p268_319
# Analyzing: p268_320
# Analyzing: p268_321
# Analyzing: p268_322
# Analyzing: p268_323
# Analyzing: p268_324
# Analyzing: p268_325
# Analyzing: p268_326
# Analyzing: p268_327
# Analyzing: p268_328
# Analyzing: p268_329
# Analyzing: p268_330
# Analyzing: p268_331
# Analyzing: p268_332
# Analyzing: p268_333
# Analyzing: p268_334
# Analyzing: p268_335
# Analyzing: p268_336
# Analyzing: p268_337
# Analyzing: p268_338
# Analyzing: p268_339
# Analyzing: p268_340
# Analyzing: p268_341
# Analyzing: p268_342
# Analyzing: p268_343
# Analyzing: p268_344
# Analyzing: p268_345
# Analyzing: p268_346
# Analyzing: p268_347
# Analyzing: p268_348
# Analyzing: p268_349
# Analyzing: p268_350
# Analyzing: p268_351
# Analyzing: p268_352
# Analyzing: p268_353
# Analyzing: p268_354
# Analyzing: p268_355
# Analyzing: p268_356
# Analyzing: p268_357
# Analyzing: p268_358
# Analyzing: p268_359
# Analyzing: p268_360
# Analyzing: p268_361
# Analyzing: p268_362
# Analyzing: p268_363
# Analyzing: p268_364
# Analyzing: p268_365
# Analyzing: p268_366
# Analyzing: p268_367
# Analyzing: p268_368
# Analyzing: p268_369
# Analyzing: p268_370
# Analyzing: p268_371
# Analyzing: p268_372
# Analyzing: p268_373
# Analyzing: p268_374
# Analyzing: p268_375
# Analyzing: p268_376
# Analyzing: p268_377
# Analyzing: p268_378
# Analyzing: p268_379
# Analyzing: p268_380
# Analyzing: p268_381
# Analyzing: p268_382
# Analyzing: p268_383
# Analyzing: p268_384
# Analyzing: p268_385
# Analyzing: p268_386
# Analyzing: p268_387
# Analyzing: p268_388
# Analyzing: p268_389
# Analyzing: p268_390
# Analyzing: p268_391
# Analyzing: p268_392
# Analyzing: p268_393
# Analyzing: p268_394
# Analyzing: p268_395
# Analyzing: p268_396
# Analyzing: p268_397
# Analyzing: p268_398
# Analyzing: p268_399
# Analyzing: p268_400
# Analyzing: p268_401
# Analyzing: p268_402
# Analyzing: p268_403
# Analyzing: p268_404
# Analyzing: p268_405
# Analyzing: p268_406
# Analyzing: p268_407
# Analyzing: p268_408
# Analyzing: p268_409
# Analyzing: p268_410
# Analyzing: p268_411
# Analyzing: p269_001
# Analyzing: p269_002
# Analyzing: p269_003
# Analyzing: p269_004
# Analyzing: p269_005
# Analyzing: p269_006
# Analyzing: p269_007
# Analyzing: p269_008
# Analyzing: p269_009
# Analyzing: p269_010
# Analyzing: p269_011
# Analyzing: p269_012
# Analyzing: p269_013
# Analyzing: p269_014
# Analyzing: p269_015
# Analyzing: p269_016
# Analyzing: p269_017
# Analyzing: p269_018
# Analyzing: p269_019
# Analyzing: p269_020
# Analyzing: p269_021
